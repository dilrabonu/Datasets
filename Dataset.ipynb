# %% [markdown]
# <a href="https://colab.research.google.com/github/dilrabonu/python-step1/blob/main/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.random.randn(3, 4), index=list("abc"), columns=["Olma", "Anor", "qOBUN", "Anjir"])
df
# Out:
#        Olma      Anor     qOBUN     Anjir
# a  1.291852 -1.071980 -2.352621  0.570093
# b -1.141514  0.949607 -0.075934 -1.320147
# c -0.491476 -1.270995  1.467093  0.148375

# %%
df.abs()
# Out:
#        Olma      Anor     qOBUN     Anjir
# a  1.291852  1.071980  2.352621  0.570093
# b  1.141514  0.949607  0.075934  1.320147
# c  0.491476  1.270995  1.467093  0.148375

# %%
df.round()
# Out:
#    Olma  Anor  qOBUN  Anjir
# a   1.0  -1.0   -2.0    1.0
# b  -1.0   1.0   -0.0   -1.0
# c  -0.0  -1.0    1.0    0.0

# %%
df.mean()
# Out:
# Olma    -0.113713
# Anor    -0.464456
# qOBUN   -0.320488
# Anjir   -0.200560
# dtype: float64

# %%
df.apply(np.abs)
# Out:
#        Olma      Anor     qOBUN     Anjir
# a  1.291852  1.071980  2.352621  0.570093
# b  1.141514  0.949607  0.075934  1.320147
# c  0.491476  1.270995  1.467093  0.148375

# %%
df.apply(sum)
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni','aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum()
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
df2.head()
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317

# %%
df2.sum()
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
df2.mean()
# Out:
# 2020    28118.666667
# 2021    20789.000000
# dtype: float64

# %%
df.mean()
# Out:
# maydoni    3.399231e+04
# aholisi    1.765062e+06
# dtype: float64

# %%
df2.mean(axis=1)
# Out:
# Labo       6031.5
# Damas     32285.5
# Spark     11427.5
# Nexia     28052.5
# Cobalt    40609.0
# Gentra    28317.0
# dtype: float64

# %%
df.count()
# Out:
# maydoni    13
# aholisi    13
# dtype: int64

# %%
df.median()
# Out:
# maydoni      16400.0
# aholisi    1676000.0
# dtype: float64

# %%
df.mad()
# Out:
# <ipython-input-13-9d6954358b36>:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df.mad()
# maydoni     32034.319527
# aholisi    702866.272189
# dtype: float64

# %%
df.prod()
# Out:
# maydoni    1.538590e+55
# aholisi    2.913892e+80
# dtype: float64

# %%
df2.prod()
# Out:
# 2020      61887297365967808
# 2021    9151971529123863600
# dtype: int64

# %%
df2.var()
# Out:
# 2020    2.345422e+08
# 2021    1.715435e+08
# dtype: float64

# %%
df.idxmin()
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: object

# %%
df.idxmax()
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: object

# %%
df["maydoni"].idxmin()
# Out:
# 'Andijon viloyati'

# %%
df["aholisi"].idxmax()
# Out:
# 'Toshkent viloyati'

# %%
df["aholisi"].argmax()
# Out:
# 12

# %%
df.iloc[12]
# Out:
# maydoni      15300.0
# aholisi    4450000.0
# Name: Toshkent viloyati, dtype: float64

# %%
df2.diff()
# Out:
#            2020     2021
# Labo        NaN      NaN
# Damas   26368.0  26140.0
# Spark  -14519.0 -27197.0
# Nexia   25293.0   7957.0
# Cobalt   3238.0  21875.0
# Gentra -14533.0 -10051.0

# %%
df2.pct_change()
# Out:
#             2020      2021
# Labo         NaN       NaN
# Damas   5.832338  3.465924
# Spark  -0.470038 -0.807464
# Nexia   1.545082  1.226985
# Cobalt  0.077719  1.514679
# Gentra -0.323668 -0.276757

# %%
df=pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/car_details.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-4fa8e52d5fa8> in <cell line: 1>()
# ----> 1 df=pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/car_details.csv", index_col=0)
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
