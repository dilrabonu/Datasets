# %% [markdown]
# <a href="https://colab.research.google.com/github/dilrabonu/python-step1/blob/main/DataFrame_ustun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data= ({
     "Yil" :[2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014],
     "Aholi soni":[36.6, 35.5, 34.3, 32.9, 32.4, 31.8, 31.1, 31.2, 30.5, 29.7],
     "Temp": [1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53, 1.50, 1.23]
})

# %%
df=pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2023        36.6  1.54
# 1  2022        35.5  1.48
# 2  2021        34.3  1.56
# 3  2020        32.9  1.62
# 4  2019        32.4  1.65
# 5  2018        31.8  1.66
# 6  2017        31.1  1.64
# 7  2016        31.2  1.53
# 8  2015        30.5  1.50
# 9  2014        29.7  1.23

# %%
df.head()
# Out:
#     Yil  Aholi soni  Temp
# 0  2023        36.6  1.54
# 1  2022        35.5  1.48
# 2  2021        34.3  1.56
# 3  2020        32.9  1.62
# 4  2019        32.4  1.65

# %%
df.head(3)
# Out:
#     Yil  Aholi soni  Temp
# 0  2023        36.6  1.54
# 1  2022        35.5  1.48
# 2  2021        34.3  1.56

# %%
df.shape
# Out:
# (10, 3)

# %%
df.size
# Out:
# 30

# %%
df.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of     Yil  Aholi soni  Temp
# 0  2023        36.6  1.54
# 1  2022        35.5  1.48
# 2  2021        34.3  1.56
# 3  2020        32.9  1.62
# 4  2019        32.4  1.65
# 5  2018        31.8  1.66
# 6  2017        31.1  1.64
# 7  2016        31.2  1.53
# 8  2015        30.5  1.50
# 9  2014        29.7  1.23>

# %%
df.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of     Yil  Aholi soni  Temp
# 0  2023        36.6  1.54
# 1  2022        35.5  1.48
# 2  2021        34.3  1.56
# 3  2020        32.9  1.62
# 4  2019        32.4  1.65
# 5  2018        31.8  1.66
# 6  2017        31.1  1.64
# 7  2016        31.2  1.53
# 8  2015        30.5  1.50
# 9  2014        29.7  1.23>

# %%
df.iloc[5]
# Out:
# Yil           2018.00
# Aholi soni      31.80
# Temp             1.66
# Name: 5, dtype: float64

# %%
df=pd.DataFrame(data, columns=["Yil", "Temp", "Aholi soni"])
df
# Out:
#     Yil  Temp  Aholi soni
# 0  2023  1.54        36.6
# 1  2022  1.48        35.5
# 2  2021  1.56        34.3
# 3  2020  1.62        32.9
# 4  2019  1.65        32.4
# 5  2018  1.66        31.8
# 6  2017  1.64        31.1
# 7  2016  1.53        31.2
# 8  2015  1.50        30.5
# 9  2014  1.23        29.7

# %%
df=pd.DataFrame(data, columns=["Yil", "Temp", "Aholi soni", "YAIM"])
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 0  2023  1.54        36.6  NaN
# 1  2022  1.48        35.5  NaN
# 2  2021  1.56        34.3  NaN
# 3  2020  1.62        32.9  NaN
# 4  2019  1.65        32.4  NaN
# 5  2018  1.66        31.8  NaN
# 6  2017  1.64        31.1  NaN
# 7  2016  1.53        31.2  NaN
# 8  2015  1.50        30.5  NaN
# 9  2014  1.23        29.7  NaN

# %%
df=pd.DataFrame(data, columns=["Yil", "Temp", "Aholi soni", "YAIM"], index= [23, 22, 21, 20, 19, 18, 17, 16, 15, 14])
df
# Out:
#      Yil  Temp  Aholi soni YAIM
# 23  2023  1.54        36.6  NaN
# 22  2022  1.48        35.5  NaN
# 21  2021  1.56        34.3  NaN
# 20  2020  1.62        32.9  NaN
# 19  2019  1.65        32.4  NaN
# 18  2018  1.66        31.8  NaN
# 17  2017  1.64        31.1  NaN
# 16  2016  1.53        31.2  NaN
# 15  2015  1.50        30.5  NaN
# 14  2014  1.23        29.7  NaN

# %%
df.Temp
# Out:
# 23    1.54
# 22    1.48
# 21    1.56
# 20    1.62
# 19    1.65
# 18    1.66
# 17    1.64
# 16    1.53
# 15    1.50
# 14    1.23
# Name: Temp, dtype: float64

# %%
df ["Aholi soni"]
# Out:
# 23    36.6
# 22    35.5
# 21    34.3
# 20    32.9
# 19    32.4
# 18    31.8
# 17    31.1
# 16    31.2
# 15    30.5
# 14    29.7
# Name: Aholi soni, dtype: float64

# %%
df.YAIM=0

# %%
df
# Out:
#      Yil  Temp  Aholi soni  YAIM
# 23  2023  1.54        36.6     0
# 22  2022  1.48        35.5     0
# 21  2021  1.56        34.3     0
# 20  2020  1.62        32.9     0
# 19  2019  1.65        32.4     0
# 18  2018  1.66        31.8     0
# 17  2017  1.64        31.1     0
# 16  2016  1.53        31.2     0
# 15  2015  1.50        30.5     0
# 14  2014  1.23        29.7     0

# %%
val= pd.Series([1700, 1600, 1500, 1650], index= [23, 18, 16, 20])
df.YAIM= val
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 23  2023  1.54        36.6  1700.0
# 22  2022  1.48        35.5     NaN
# 21  2021  1.56        34.3     NaN
# 20  2020  1.62        32.9  1650.0
# 19  2019  1.65        32.4     NaN
# 18  2018  1.66        31.8  1600.0
# 17  2017  1.64        31.1     NaN
# 16  2016  1.53        31.2  1500.0
# 15  2015  1.50        30.5     NaN
# 14  2014  1.23        29.7     NaN

# %%
df["Result"] = df.YAIM
df
# Out:
#      Yil  Temp  Aholi soni    YAIM  Result
# 23  2023  1.54        36.6  1700.0  1700.0
# 22  2022  1.48        35.5     NaN     NaN
# 21  2021  1.56        34.3     NaN     NaN
# 20  2020  1.62        32.9  1650.0  1650.0
# 19  2019  1.65        32.4     NaN     NaN
# 18  2018  1.66        31.8  1600.0  1600.0
# 17  2017  1.64        31.1     NaN     NaN
# 16  2016  1.53        31.2  1500.0  1500.0
# 15  2015  1.50        30.5     NaN     NaN
# 14  2014  1.23        29.7     NaN     NaN

# %%
df.YAIM >1500
df
# Out:
#      Yil  Temp  Aholi soni    YAIM  Result
# 23  2023  1.54        36.6  1700.0  1700.0
# 22  2022  1.48        35.5     NaN     NaN
# 21  2021  1.56        34.3     NaN     NaN
# 20  2020  1.62        32.9  1650.0  1650.0
# 19  2019  1.65        32.4     NaN     NaN
# 18  2018  1.66        31.8  1600.0  1600.0
# 17  2017  1.64        31.1     NaN     NaN
# 16  2016  1.53        31.2  1500.0  1500.0
# 15  2015  1.50        30.5     NaN     NaN
# 14  2014  1.23        29.7     NaN     NaN

# %%
df["Result"] = df.YAIM>1500
df
# Out:
#      Yil  Temp  Aholi soni    YAIM  Result
# 23  2023  1.54        36.6  1700.0    True
# 22  2022  1.48        35.5     NaN   False
# 21  2021  1.56        34.3     NaN   False
# 20  2020  1.62        32.9  1650.0    True
# 19  2019  1.65        32.4     NaN   False
# 18  2018  1.66        31.8  1600.0    True
# 17  2017  1.64        31.1     NaN   False
# 16  2016  1.53        31.2  1500.0   False
# 15  2015  1.50        30.5     NaN   False
# 14  2014  1.23        29.7     NaN   False

# %%
del df["Result"]
df
# Out:
#      Yil  Temp  Aholi soni    YAIM
# 23  2023  1.54        36.6  1700.0
# 22  2022  1.48        35.5     NaN
# 21  2021  1.56        34.3     NaN
# 20  2020  1.62        32.9  1650.0
# 19  2019  1.65        32.4     NaN
# 18  2018  1.66        31.8  1600.0
# 17  2017  1.64        31.1     NaN
# 16  2016  1.53        31.2  1500.0
# 15  2015  1.50        30.5     NaN
# 14  2014  1.23        29.7     NaN

# %%
data= {"Uzbekistan":{2021: 33.9, 2020: 33.8, 2019:33.6, 2018: 33.5, 2017: 33.0},
       "Kazakhstan":{2021: 18.9, 2020: 18.8, 2019:18.7, 2018: 18.6, 2017:18.2, 2016: 17.9}
       }

# %%
df2= pd.DataFrame (data)
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.8        18.8
# 2019        33.6        18.7
# 2018        33.5        18.6
# 2017        33.0        18.2
# 2016         NaN        17.9

# %%
df2.index.name= "Yil"
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.8        18.8
# 2019        33.6        18.7
# 2018        33.5        18.6
# 2017        33.0        18.2
# 2016         NaN        17.9

# %%
df2= pd.DataFrame(data, index=[2021, 2019, 2017])
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        33.6        18.7
# 2017        33.0        18.2

# %%
df2.T
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  33.6  33.0
# Kazakhstan  18.9  18.7  18.2

# %%
df2.values
# Out:
# array([[33.9, 18.9],
#        [33.6, 18.7],
#        [33. , 18.2]])

# %%
arr=df2.values

# %%
arr
# Out:
# array([[33.9, 18.9],
#        [33.6, 18.7],
#        [33. , 18.2]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
df2.index.name= "Yil"
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2019        33.6        18.7
# 2017        33.0        18.2

# %%
df3=pd.DataFrame ([2021, 2014, 2017, 2013])
df3
# Out:
#       0
# 0  2021
# 1  2014
# 2  2017
# 3  2013

# %%
df3.isin(df2)
# Out:
#        0
# 0  False
# 1  False
# 2  False
# 3  False

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2019        33.6        18.7
# 2017        33.0        18.2

# %%
df2.index.delete(0)
# Out:
# Int64Index([2019, 2017], dtype='int64', name='Yil')

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2019        33.6        18.7
# 2017        33.0        18.2

# %%
df2.index.insert(3, 2023)
# Out:
# Int64Index([2021, 2019, 2017, 2023], dtype='int64', name='Yil')
