# %% [markdown]
# <a href="https://colab.research.google.com/github/dilrabonu/python-step1/blob/main/fayllarno_oqiw_yoziw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import xlrd

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Out:
# --2023-12-14 13:11:17--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv’
#
# merc.csv            100%[===================>] 710.98K  --.-KB/s    in 0.06s
#
# 2023-12-14 13:11:18 (11.3 MB/s) - ‘merc.csv’ saved [728047/728047]

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93
# Receiving objects: 100% (145/145), 9.72 MiB | 3.89 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
df=pd.read_csv("merc.csv")#faylni ochib, oqish
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df1=pd.read_csv("sample_data/california_housing_test.csv")
df1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
df2
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
# !wget https://github.com/anvarnarz/praktikum_datasets/blob/main/uzbekistan.xlsx
# Out:
# --2023-12-14 13:11:29--  https://github.com/anvarnarz/praktikum_datasets/blob/main/uzbekistan.xlsx
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7061 (6.9K) [text/plain]
# Saving to: ‘uzbekistan.xlsx’
#
# uzbekistan.xlsx     100%[===================>]   6.90K  --.-KB/s    in 0s
#
# 2023-12-14 13:11:29 (82.8 MB/s) - ‘uzbekistan.xlsx’ saved [7061/7061]

# %%
# !wget https://github.com/anvarnarz/praktikum_datasets/blob/main/uzbekistan.xlsx
# Out:
# --2023-12-14 13:11:30--  https://github.com/anvarnarz/praktikum_datasets/blob/main/uzbekistan.xlsx
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7051 (6.9K) [text/plain]
# Saving to: ‘uzbekistan.xlsx.1’
#
# uzbekistan.xlsx.1   100%[===================>]   6.89K  --.-KB/s    in 0s
#
# 2023-12-14 13:11:31 (87.7 MB/s) - ‘uzbekistan.xlsx.1’ saved [7051/7051]

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv
# Out:
# --2023-12-14 13:11:39--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3146 (3.1K) [text/plain]
# Saving to: ‘automobile_data.csv’
#
# automobile_data.csv 100%[===================>]   3.07K  --.-KB/s    in 0s
#
# 2023-12-14 13:11:39 (38.0 MB/s) - ‘automobile_data.csv’ saved [3146/3146]

# %%
pd.read_csv("automobile_data.csv")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df1=pd.read_csv("automobile_data.csv", index_col="index", nrows=15)
df1
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
df1.to_csv("cars.csv", index=False, columns=["company", "length", "price"])

# %%
df1.to_csv("drive/MyDrive/MySuccess/cars.csv", index=False, columns=["company", "length", "price"])

# %%
df1
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
pd.read_csv("cars.csv")
# Out:
#         company  length  price
# 0   alfa-romero   168.8  13495
# 1   alfa-romero   168.8  16500
# 2   alfa-romero   171.2  16500
# 3          audi   176.6  13950
# 4          audi   176.6  17450
# 5          audi   177.3  15250
# 6          audi   192.7  18920
# 7           bmw   176.8  16430
# 8           bmw   176.8  16925
# 9           bmw   176.8  20970
# 10          bmw   189.0  30760
# 11          bmw   193.8  41315
# 12          bmw   197.0  36880
# 13    chevrolet   141.1   5151
# 14    chevrolet   155.9   6295

# %%
pip install xlrd

# %%
pip install pyexcel-xlsx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 1.0 MB/s eta 0:00:00
# ...

# %%
df5=pd.read_excel("praktikum_datasets/uzbekistan.xlsx")
df5
# Out:
#                        Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0                Andijon viloyati             4200  1899000
# 1                 Buxoro viloyati            39400  1384700
# 2               Fargʻona viloyati             6800  2597000
# 3                 Jizzax viloyati            20500   910500
# 4                 Xorazm viloyati             6300  1200000
# 5               Namangan viloyati             7900  1862000
# 6                 Navoiy viloyati           110800   767500
# 7            Qashqadaryo viloyati            28400  2029000
# 8   Qoraqalpogʻiston Respublikasi           160000  1200000
# 9              Samarqand viloyati            16400  2322000
# 10              Sirdaryo viloyati             5100   648100
# 11           Surxondaryo viloyati            20800  1676000
# 12              Toshkent viloyati            15300  4450000

# %%
df5.to_excel("uzbinf.xlsx")

# %%
df5
# Out:
#                        Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0                Andijon viloyati             4200  1899000
# 1                 Buxoro viloyati            39400  1384700
# 2               Fargʻona viloyati             6800  2597000
# 3                 Jizzax viloyati            20500   910500
# 4                 Xorazm viloyati             6300  1200000
# 5               Namangan viloyati             7900  1862000
# 6                 Navoiy viloyati           110800   767500
# 7            Qashqadaryo viloyati            28400  2029000
# 8   Qoraqalpogʻiston Respublikasi           160000  1200000
# 9              Samarqand viloyati            16400  2322000
# 10              Sirdaryo viloyati             5100   648100
# 11           Surxondaryo viloyati            20800  1676000
# 12              Toshkent viloyati            15300  4450000

# %%
df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
hdfobj=pd.HDFStore("data.h5")
hdfobj.put("uzdata", df5)
hdfobj.put("cardata", df)

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hdfobj["uzdata"]
# Out:
#                        Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0                Andijon viloyati             4200  1899000
# 1                 Buxoro viloyati            39400  1384700
# 2               Fargʻona viloyati             6800  2597000
# 3                 Jizzax viloyati            20500   910500
# 4                 Xorazm viloyati             6300  1200000
# 5               Namangan viloyati             7900  1862000
# 6                 Navoiy viloyati           110800   767500
# 7            Qashqadaryo viloyati            28400  2029000
# 8   Qoraqalpogʻiston Respublikasi           160000  1200000
# 9              Samarqand viloyati            16400  2322000
# 10              Sirdaryo viloyati             5100   648100
# 11           Surxondaryo viloyati            20800  1676000
# 12              Toshkent viloyati            15300  4450000

# %%
hdfobj["cardata"]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
hdfobj.close()

# %%
hdfobj=pd.HDFStore("data.h5")

# %%
hdfobj["uzdata"]
# Out:
#                        Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0                Andijon viloyati             4200  1899000
# 1                 Buxoro viloyati            39400  1384700
# 2               Fargʻona viloyati             6800  2597000
# 3                 Jizzax viloyati            20500   910500
# 4                 Xorazm viloyati             6300  1200000
# 5               Namangan viloyati             7900  1862000
# 6                 Navoiy viloyati           110800   767500
# 7            Qashqadaryo viloyati            28400  2029000
# 8   Qoraqalpogʻiston Respublikasi           160000  1200000
# 9              Samarqand viloyati            16400  2322000
# 10              Sirdaryo viloyati             5100   648100
# 11           Surxondaryo viloyati            20800  1676000
# 12              Toshkent viloyati            15300  4450000

# %%
hdfobj.close()

# %%
tashkent=pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
len(tashkent)#tashkent fayilida nechta dataframe borligini korsatadi
# Out:
# 19

# %%
tashkent[0]
# Out:
#                             Tashkent  ТошкентToshkent  \
# 0                                        Capital city
# 1   .mw-parser-output .tmulti .multiimageinner{dis...
# 2   .mw-parser-output .ib-settlement-cols{text-ali...
# 3                             Nickname: Tash (A rock)
# 4   Motto(s): Kuch Adolatdadir! ("Strength is in J...
# 5                  Location of Tashkent in Uzbekistan
# 6   .mw-parser-output .locmap .od{position:absolut...
# 7   Coordinates: .mw-parser-output .geo-default,.m...
# 8                                             Country
# 9                                             Settled
# 10                                          Divisions
# 11                                         Government
# 12                                             • Type
# 13                                    • Hakim (Mayor)
# 14                                               Area
# 15                                     • Capital city
# ...

# %%
tashkent[8]
# Out:
#     Year     Pop. ±% p.a.
# 0   2007  2157100  +0.77%
# 1   2008  2180000  +1.06%
# 2   2009  2206300  +1.21%
# 3   2010  2234300  +1.27%
# 4   2011  2296500  +2.78%
# 5   2012  2309300  +0.56%
# 6   2013  2340900  +1.37%
# 7   2014  2352900  +0.51%
# 8   2015  2371300  +0.78%
# 9   2016  2393200  +0.92%
# 10  2017  2424100  +1.29%
# 11  2018  2464900  +1.68%
# 12  2019  2509900  +1.83%
# 13  2020  2571700  +2.46%
# 14  2021  2694400  +4.77%

# %%
import requests
r=requests.get("https://openlibrary.org/subjects/python.json?published_in=2010-2020")

# %%
r.status_code
# Out:
# 200

# %%
pd.DataFrame(r.json()["works"])
# Out:
#                    key                                              title  \
# 0    /works/OL2784125W                                    Learning Python
# 1    /works/OL2784127W                                             Python
# 2   /works/OL17795703W                          Python for bioinformatics
# 3   /works/OL15664278W                                  Head First Python
# 4    /works/OL6045694W                               Python in a Nutshell
# 5   /works/OL23330617W                        Making music with computers
# 6   /works/OL17422847W                           Python For Data Analysis
# 7   /works/OL14940051W            Natural Language Processing With Python
# 8   /works/OL21703042W                               Tour of Data Science
# 9   /works/OL21349037W  Introduction to Python for Science and Enginee...
# 10   /works/OL8167555W             Twisted Network Programming Essentials
# 11  /works/OL19548251W                                Python for Everyone
#
# ...
